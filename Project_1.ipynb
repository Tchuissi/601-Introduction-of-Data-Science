# %% [markdown]
# <a href="https://colab.research.google.com/github/Tchuissi/601-Introduction-of-Data-Science/blob/master/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -

# %%
import pandas as pd

# %%
xls=pd.ExcelFile("Liste des films ayant réalisé plus d'un million d'entrées.xlsx")
#Project_1

# %%
df_19 = pd.read_excel(xls, '2019')
df_18 = pd.read_excel(xls, '2018')
df_17 = pd.read_excel(xls, '2017')
df_16 = pd.read_excel(xls, '2016')
df_15 = pd.read_excel(xls, '2015')
df_14 = pd.read_excel(xls, '2014')
df_13 = pd.read_excel(xls, '2013')
df_12 = pd.read_excel(xls, '2012')
df_11 = pd.read_excel(xls, '2011')
df_10 = pd.read_excel(xls, '2010')
df_9 = pd.read_excel(xls, '2009')
df_8 = pd.read_excel(xls, '2008')
df_7 = pd.read_excel(xls, '2007')
df_6 = pd.read_excel(xls, '2006')
df_5 = pd.read_excel(xls, '2005')
df_4 = pd.read_excel(xls, '2004')
df_3 = pd.read_excel(xls, '2003')

# %%
l=[df_19, df_18, df_17, df_16, df_15, df_14, df_13, df_12, df_11, df_10, df_9, df_8, df_7,df_6, df_5, df_4, df_3 ]

for i in l:
  i=i[5:]
  #print(i)

# %% [markdown]
# - after cleaning all the dataframes, add a new column for the year
# - assembly all the dataframes into one

# %%
df_16
# Out:
#                                            Unnamed: 0  ...          Unnamed: 4
# 0   Retour au menu "Films ayant réalisé plus d'un ...  ...                 NaN
# 1                                                 NaN  ...                 NaN
# 2                                                 NaN  ...                 NaN
# 3                                                2016  ...                 NaN
# 4                                                 NaN  ...                 NaN
# 5                                                rang  ...  entrées (millions)
# 6                                                   1  ...             4754973
# 7                                                   2  ...             4604904
# 8                                                   3  ...             4525149
# 9                                                   4  ...             3918856
# 10                                                  5  ...             3843618
# ...
